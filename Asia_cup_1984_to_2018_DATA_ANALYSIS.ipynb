# %% [markdown]
# # IPL DATA ANALYSIS
#
# Arya Chauhan (2023CA22)
# Devesh (2023CA33)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_csv("Asia_cup_1984_to_2018.csv")
df=pd.DataFrame(data)
df
# Out:
#      Match_id        Team1       Team2 Format        Ground  Year  \
# 0           1     Pakistan   Sri Lanka    ODI       Sharjah  1984
# 1           2        India   Sri Lanka    ODI       Sharjah  1984
# 2           3        India    Pakistan    ODI       Sharjah  1984
# 3           4    Sri Lanka    Pakistan    ODI  Colombo(PSS)  1986
# 4           5   Bangladesh    Pakistan    ODI      Moratuwa  1986
# ..        ...          ...         ...    ...           ...   ...
# 109       110        India    Pakistan    ODI    Dubai(DSC)  2018
# 110       111  Afghanistan  Bangladesh    ODI     Abu Dhabi  2018
# 111       112  Afghanistan       India    ODI    Dubai(DSC)  2018
# 112       113   Bangladesh    Pakistan    ODI     Abu Dhabi  2018
# 113       114   Bangladesh       India    ODI    Dubai(DSC)  2018
#
#             Toss Selection  fi_score  fi_wickets  ...      Result  si_score  \
# 0      Sri Lanka   Bowling       187           9  ...   Sri Lanka       190
# ...

# %%
#Dividing the given dataframe into two dataframe ODI and T20I
df1=df[df['Format']=="ODI"]
df1
# Out:
#      Match_id        Team1       Team2 Format        Ground  Year  \
# 0           1     Pakistan   Sri Lanka    ODI       Sharjah  1984
# 1           2        India   Sri Lanka    ODI       Sharjah  1984
# 2           3        India    Pakistan    ODI       Sharjah  1984
# 3           4    Sri Lanka    Pakistan    ODI  Colombo(PSS)  1986
# 4           5   Bangladesh    Pakistan    ODI      Moratuwa  1986
# ..        ...          ...         ...    ...           ...   ...
# 109       110        India    Pakistan    ODI    Dubai(DSC)  2018
# 110       111  Afghanistan  Bangladesh    ODI     Abu Dhabi  2018
# 111       112  Afghanistan       India    ODI    Dubai(DSC)  2018
# 112       113   Bangladesh    Pakistan    ODI     Abu Dhabi  2018
# 113       114   Bangladesh       India    ODI    Dubai(DSC)  2018
#
#             Toss Selection  fi_score  fi_wickets  ...      Result  si_score  \
# 0      Sri Lanka   Bowling       187           9  ...   Sri Lanka       190
# ...

# %%
df2=df[df['Format']=="T20I"]
df2
# Out:
#      Match_id       Team1      Team2 Format  Ground  Year        Toss  \
# 90         91  Bangladesh      India   T20I  Mirpur  2016  Bangladesh
# 91         92   Sri Lanka        UAE   T20I  Mirpur  2016         UAE
# 92         93  Bangladesh        UAE   T20I  Mirpur  2016         UAE
# 93         94       India   Pakistan   T20I  Mirpur  2016       India
# 94         95  Bangladesh  Sri Lanka   T20I  Mirpur  2016  Bangladesh
# 95         96    Pakistan        UAE   T20I  Mirpur  2016         UAE
# 96         97       India  Sri Lanka   T20I  Mirpur  2016       India
# 97         98  Bangladesh   Pakistan   T20I  Mirpur  2016    Pakistan
# 98         99       India        UAE   T20I  Mirpur  2016         UAE
# 99        100    Pakistan  Sri Lanka   T20I  Mirpur  2016    Pakistan
# 100       101  Bangladesh      India   T20I  Mirpur  2016       India
#
#     Selection  fi_score  fi_wickets  ...      Result  si_score  si_wickets  \
# ...

# %%
#shape and Dimension of the dataframe
print("The shape of the dataframe is ",df.shape)
print("The Dimension of the dataframe is ",df.ndim,"D")
# Out:
# The shape of the dataframe is  (114, 28)
# The Dimension of the dataframe is  2 D

# %%
# Here simply we are describing the dataframe
df.describe()
# Out:
#          Match_id         Year    fi_score  fi_wickets       fi_4s  \
# count  114.000000   114.000000  114.000000  114.000000  114.000000
# mean    57.500000  2005.184211  201.745614    6.771930   15.771930
# std     33.052988    10.325298   65.448191    3.074402    7.450171
# min      1.000000  1984.000000    0.000000    0.000000    0.000000
# 25%     29.250000  1997.000000  153.000000    4.000000   10.250000
# 50%     57.500000  2008.000000  204.500000    8.000000   16.000000
# 75%     85.750000  2014.000000  250.500000   10.000000   20.000000
# max    114.000000  2018.000000  330.000000   10.000000   35.000000
#
#             fi_6s    fi_extra  fi_run_rate  fi_avg_str_rate  fi_max_score  \
# count  114.000000  114.000000   114.000000       114.000000    114.000000
# mean     2.324561   13.868421     4.885088        70.032368     69.017544
# std      2.188043    8.148525     1.320551        27.890933     31.066011
# ...

# %%
# Here simply we are giving the info of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Match_id             114 non-null    int64
#  1   Team1                114 non-null    object
#  2   Team2                114 non-null    object
#  3   Format               114 non-null    object
#  4   Ground               114 non-null    object
#  5   Year                 114 non-null    int64
#  6   Toss                 114 non-null    object
#  7   Selection            114 non-null    object
#  8   fi_score             114 non-null    int64
#  9   fi_wickets           114 non-null    int64
#  10  fi_4s                114 non-null    int64
#  11  fi_6s                114 non-null    int64
#  12  fi_extra             114 non-null    int64
#  13  fi_run_rate          114 non-null    float64
#  14  fi_avg_str_rate      114 non-null    float64
# ...

# %%
#showing all columns of dataframe
df.columns
# Out:
# Index(['Match_id', 'Team1', 'Team2', 'Format', 'Ground', 'Year', 'Toss',
#        'Selection', 'fi_score', 'fi_wickets', 'fi_4s', 'fi_6s', 'fi_extra',
#        'fi_run_rate', 'fi_avg_str_rate', 'fi_max_score', 'fi_max_indv_wickets',
#        'PlayerOfTheMatch', 'Result', 'si_score', 'si_wickets', 'si_4s',
#        'si_6s', 'si_extras', 'si_run_rate', 'si_avg_str_rate', 'si_max_score',
#        'si_max_indv_wickets'],
#       dtype='object')

# %%
# showing first and last 10 rows of dataframe
print("First ten rows of the dataframe")
df.head(10)
# Out:
# First ten rows of the dataframe
#    Match_id       Team1       Team2 Format        Ground  Year        Toss  \
# 0         1    Pakistan   Sri Lanka    ODI       Sharjah  1984   Sri Lanka
# 1         2       India   Sri Lanka    ODI       Sharjah  1984       India
# 2         3       India    Pakistan    ODI       Sharjah  1984       India
# 3         4   Sri Lanka    Pakistan    ODI  Colombo(PSS)  1986   Sri Lanka
# 4         5  Bangladesh    Pakistan    ODI      Moratuwa  1986    Pakistan
# 5         6   Sri Lanka  Bangladesh    ODI         Kandy  1986  Bangladesh
# 6         7   Sri Lanka    Pakistan    ODI  Colombo(SSC)  1986   Sri Lanka
# 7         8    Pakistan   Sri Lanka    ODI         Dhaka  1988   Sri Lanka
# 8         9  Bangladesh       India    ODI    Chattogram  1988       India
# 9        10       India   Sri Lanka    ODI         Dhaka  1988       India
#
#   Selection  fi_score  fi_wickets  ...      Result  si_score  si_wickets  \
# ...

# %%
# showing last 10 rows of dataframe
print("Last 10 rows of the dataframe")
df.tail(10)
# Out:
# Last 10 rows of the dataframe
#      Match_id        Team1       Team2 Format      Ground  Year         Toss  \
# 104       105    Hong Kong       India    ODI  Dubai(DSC)  2018    Hong Kong
# 105       106        India    Pakistan    ODI  Dubai(DSC)  2018     Pakistan
# 106       107  Afghanistan  Bangladesh    ODI   Abu Dhabi  2018  Afghanistan
# 107       108   Bangladesh       India    ODI  Dubai(DSC)  2018        India
# 108       109  Afghanistan    Pakistan    ODI   Abu Dhabi  2018  Afghanistan
# 109       110        India    Pakistan    ODI  Dubai(DSC)  2018     Pakistan
# 110       111  Afghanistan  Bangladesh    ODI   Abu Dhabi  2018   Bangladesh
# 111       112  Afghanistan       India    ODI  Dubai(DSC)  2018  Afghanistan
# 112       113   Bangladesh    Pakistan    ODI   Abu Dhabi  2018   Bangladesh
# 113       114   Bangladesh       India    ODI  Dubai(DSC)  2018        India
#
#     Selection  fi_score  fi_wickets  ...       Result  si_score  si_wickets  \
# ...

# %%
#MATCHES PLAYED BY TEAMS ON EVERY GROUND and its plot
b=df.groupby("Ground")
c=b["Result"].value_counts()
print(c)
c.plot(kind="bar")
# Out:
# Ground        Result
# Abu Dhabi     Afghanistan        2
#               Bangladesh         2
#               Pakistan           1
# Chandigarh    India              1
# Chattogram    India              1
#               Pakistan           1
# Colombo(PSS)  Pakistan           1
# Colombo(RPS)  Sri Lanka          6
#               Pakistan           3
#               India              1
# Colombo(SSC)  India              2
#               Pakistan           2
#               Sri Lanka          2
#               Bangladesh         1
#               Match Cancelled    1
# Cuttack       Sri Lanka          1
# Dambulla      Sri Lanka          5
#               India              4
#               Pakistan           1
# Dhaka         Sri Lanka          5
#               Pakistan           4
#               India              3
# Dubai(DSC)    India              6
#               Bangladesh         1
#               Pakistan           1
# Fatullah      Sri Lanka          2
# ...

# %%
##COMPARING FIRST INNING AND SECOND INNING AVERAGE RUN RATE

sns.set(rc={'figure.figsize':(15,5)})
sns.set(font_scale=1.5)
sns.lineplot(x="Match_id",y="fi_run_rate",data=df)
sns.lineplot(x="Match_id",y="si_run_rate",data=df)
# Out:
# <AxesSubplot: xlabel='Match_id', ylabel='fi_run_rate'>

# %%
##COMPARING FIRST INNING AND SECOND INNING AVERAGE STRIKE RATE

sns.set(rc={'figure.figsize':(15,5)})
sns.set(font_scale=1.5)
sns.lineplot(x="Match_id",y="fi_avg_str_rate",data=df)
sns.lineplot(x="Match_id",y="si_avg_str_rate",data=df)
# Out:
# <AxesSubplot: xlabel='Match_id', ylabel='fi_avg_str_rate'>

# %% [markdown]
# # ODI FORMAT

# %%
#TOP 5 TEAM SCORE IN ODI FORMAT WHILE BATTING FIRST
temp=df1.nlargest(5,['fi_score'])
temp[['Match_id','Team1','Team2','Format','Ground','Year','Result','fi_score']]
# Out:
#     Match_id       Team1       Team2 Format    Ground  Year     Result  \
# 76        77       India    Pakistan    ODI    Mirpur  2012      India
# 86        87  Bangladesh    Pakistan    ODI    Mirpur  2014   Pakistan
# 67        68   Sri Lanka  Bangladesh    ODI  Dambulla  2010  Sri Lanka
# 62        63       India   Sri Lanka    ODI   Karachi  2008      India
# 61        62    Pakistan       India    ODI   Karachi  2008   Pakistan
#
#     fi_score
# 76       330
# 86       326
# 67       312
# 62       310
# 61       309

# %%
#TOP 5 TEAM SCORE IN ODI FORMAT WHILE CHASING
temp=df1.nlargest(5,['si_score'])
temp[['Match_id','Team1','Team2','Format','Ground','Year','Result','si_score']]
# Out:
#     Match_id       Team1      Team2 Format        Ground  Year     Result  \
# 69        70  Bangladesh   Pakistan    ODI      Dambulla  2010   Pakistan
# 55        56   Hong Kong      India    ODI       Karachi  2008      India
# 54        55  Bangladesh  Sri Lanka    ODI        Lahore  2008  Sri Lanka
# 43        44   Hong Kong   Pakistan    ODI  Colombo(SSC)  2004   Pakistan
# 60        61  Bangladesh  Sri Lanka    ODI       Karachi  2008  Sri Lanka
#
#     si_score
# 69       385
# 55       374
# 54       357
# 43       343
# 60       332

# %%
##TOP 10 HIGHEST SCORERS IN ODI FORMAT WHILE BATTING FIRST
temp=df1.nlargest(10,['fi_max_score'])
temp[['Match_id','Team1','Team2','Format','Ground','Year','PlayerOfTheMatch','fi_max_score']]
# Out:
#      Match_id        Team1      Team2 Format        Ground  Year  \
# 76         77        India   Pakistan    ODI        Mirpur  2012
# 101       102   Bangladesh  Sri Lanka    ODI    Dubai(DSC)  2018
# 27         28    Sri Lanka      India    ODI  Colombo(RPS)  1997
# 49         50    Sri Lanka      India    ODI  Colombo(RPS)  2004
# 56         57     Pakistan      India    ODI       Karachi  2008
# 111       112  Afghanistan      India    ODI    Dubai(DSC)  2018
# 61         62     Pakistan      India    ODI       Karachi  2008
# 113       114   Bangladesh      India    ODI    Dubai(DSC)  2018
# 80         81   Bangladesh      India    ODI      Fatullah  2014
# 58         59   Bangladesh      India    ODI       Karachi  2008
#
#      PlayerOfTheMatch  fi_max_score
# 76        Virat Kohli           183
# 101   Mushfiqur Rahim           144
# 27   Arjuna Ranatunga           131
# 49    Virender Sehwag           130
# 56       Suresh Raina           125
# ...

# %%
##TOP 10 HIGHEST SCORERS IN ODI FORMAT WHILE CHASING
temp=df1.nlargest(10,['si_max_score'])
temp[['Match_id','Team1','Team2','Format','Ground','Year','PlayerOfTheMatch','si_max_score']]
# Out:
#      Match_id       Team1      Team2 Format        Ground  Year  \
# 43         44   Hong Kong   Pakistan    ODI  Colombo(SSC)  2004
# 48         49       India   Pakistan    ODI  Colombo(RPS)  2004
# 80         81  Bangladesh      India    ODI      Fatullah  2014
# 33         34  Bangladesh      India    ODI         Dhaka  2000
# 60         61  Bangladesh  Sri Lanka    ODI       Karachi  2008
# 104       105   Hong Kong      India    ODI    Dubai(DSC)  2018
# 64         65       India  Sri Lanka    ODI       Karachi  2008
# 10         11  Bangladesh   Pakistan    ODI    Chattogram  1988
# 69         70  Bangladesh   Pakistan    ODI      Dambulla  2010
# 56         57    Pakistan      India    ODI       Karachi  2008
#
#       PlayerOfTheMatch  si_max_score
# 43        Shoaib Malik           144
# 48        Shoaib Malik           143
# 80         Virat Kohli           136
# 33      Sourav Ganguly           135
# 60   Sanath Jayasuriya           130
# ...

# %%
##TOP 10 HIGHEST BOWLING FIGURES IN ODI FORMAT WHILE BATTING FIRST
temp=df1.nlargest(10,['fi_max_indv_wickets'])
temp[['Match_id','Team1','Team2','Format','Ground','Year','PlayerOfTheMatch','fi_max_indv_wickets']]
# Out:
#     Match_id       Team1      Team2 Format        Ground  Year  \
# 11        12       India   Pakistan    ODI         Dhaka  1988
# 57        58   Sri Lanka        UAE    ODI        Lahore  2008
# 59        60    Pakistan  Sri Lanka    ODI       Karachi  2008
# 65        66   Sri Lanka   Pakistan    ODI      Dambulla  2010
# 70        71   Sri Lanka      India    ODI      Dambulla  2010
# 6          7   Sri Lanka   Pakistan    ODI  Colombo(SSC)  1986
# 17        18       India  Sri Lanka    ODI       Kolkata  1991
# 19        20  Bangladesh  Sri Lanka    ODI       Sharjah  1995
# 25        26   Sri Lanka   Pakistan    ODI  Colombo(RPS)  1997
# 42        43   Sri Lanka        UAE    ODI      Dambulla  2004
#
#        PlayerOfTheMatch  fi_max_indv_wickets
# 11          Arshad Ayub                    5
# 57       Ajantha Mendis                    5
# 59     Kumar Sangakkara                    5
# 65        Shahid Afridi                    5
# ...

# %%
##TOP 10 HIGHEST BOWLING FIGURES IN ODI FORMAT WHILE CHASING
temp=df1.nlargest(10,['si_max_indv_wickets'])
temp[['Match_id','Team1','Team2','Format','Ground','Year','PlayerOfTheMatch','si_max_indv_wickets']]
# Out:
#      Match_id        Team1      Team2 Format        Ground  Year  \
# 64         65        India  Sri Lanka    ODI       Karachi  2008
# 20         21        India   Pakistan    ODI       Sharjah  1995
# 26         27   Bangladesh   Pakistan    ODI  Colombo(RPS)  1997
# 60         61   Bangladesh  Sri Lanka    ODI       Karachi  2008
# 79         80     Pakistan  Sri Lanka    ODI      Fatullah  2014
# 89         90     Pakistan  Sri Lanka    ODI        Mirpur  2014
# 103       104  Afghanistan  Sri Lanka    ODI     Abu Dhabi  2018
# 4           5   Bangladesh   Pakistan    ODI      Moratuwa  1986
# 9          10        India  Sri Lanka    ODI         Dhaka  1988
# 12         13   Bangladesh  Sri Lanka    ODI         Dhaka  1988
#
#       PlayerOfTheMatch  si_max_indv_wickets
# 64      Ajantha Mendis                    6
# 20         Aaqib Javed                    5
# 26         Saeed Anwar                    5
# 60   Sanath Jayasuriya                    5
# ...

# %% [markdown]
# # T20I FORMAT

# %%
#TOP 5 TEAM SCORE IN T20I FORMAT WHILE BATTING FIRST
temp=df2.nlargest(5,['fi_score'])
temp[['Match_id','Team1','Team2','Format','Ground','Year','Result','fi_score']]
# Out:
#     Match_id       Team1      Team2 Format  Ground  Year      Result  fi_score
# 99       100    Pakistan  Sri Lanka   T20I  Mirpur  2016    Pakistan       151
# 94        95  Bangladesh  Sri Lanka   T20I  Mirpur  2016  Bangladesh       147
# 96        97       India  Sri Lanka   T20I  Mirpur  2016       India       142
# 92        93  Bangladesh        UAE   T20I  Mirpur  2016  Bangladesh       133
# 95        96    Pakistan        UAE   T20I  Mirpur  2016    Pakistan       131

# %%
#TOP 5 TEAM SCORE IN T20I FORMAT WHILE CHASING
temp=df2.nlargest(5,['si_score'])
temp[['Match_id','Team1','Team2','Format','Ground','Year','Result','si_score']]
# Out:
#     Match_id       Team1      Team2 Format  Ground  Year      Result  si_score
# 90        91  Bangladesh      India   T20I  Mirpur  2016       India       166
# 99       100    Pakistan  Sri Lanka   T20I  Mirpur  2016    Pakistan       150
# 96        97       India  Sri Lanka   T20I  Mirpur  2016       India       138
# 95        96    Pakistan        UAE   T20I  Mirpur  2016    Pakistan       129
# 97        98  Bangladesh   Pakistan   T20I  Mirpur  2016  Bangladesh       129

# %%
##TOP 5 HIGHEST SCORERS IN T20I FORMAT WHILE BATTING FIRST
temp=df2.nlargest(5,['fi_max_score'])
temp[['Match_id','Team1','Team2','Format','Ground','Year','PlayerOfTheMatch','fi_max_score']]
# Out:
#     Match_id       Team1      Team2 Format  Ground  Year PlayerOfTheMatch  \
# 94        95  Bangladesh  Sri Lanka   T20I  Mirpur  2016    Sabbir Rahman
# 95        96    Pakistan        UAE   T20I  Mirpur  2016     Shoaib Malik
# 96        97       India  Sri Lanka   T20I  Mirpur  2016      Virat Kohli
# 91        92   Sri Lanka        UAE   T20I  Mirpur  2016   Lasith Malinga
# 93        94       India   Pakistan   T20I  Mirpur  2016      Virat Kohli
#
#     fi_max_score
# 94            80
# 95            63
# 96            56
# 91            50
# 93            49

# %%
##TOP 5 HIGHEST SCORERS IN T20I FORMAT WHILE CHASING
temp=df2.nlargest(5,['si_max_score'])
temp[['Match_id','Team1','Team2','Format','Ground','Year','PlayerOfTheMatch','si_max_score']]
# Out:
#      Match_id       Team1      Team2 Format  Ground  Year PlayerOfTheMatch  \
# 90         91  Bangladesh      India   T20I  Mirpur  2016     Rohit Sharma
# 99        100    Pakistan  Sri Lanka   T20I  Mirpur  2016       Umar Akmal
# 100       101  Bangladesh      India   T20I  Mirpur  2016   Shikhar Dhawan
# 97         98  Bangladesh   Pakistan   T20I  Mirpur  2016    Soumya Sarkar
# 95         96    Pakistan        UAE   T20I  Mirpur  2016     Shoaib Malik
#
#      si_max_score
# 90             83
# 99             75
# 100            60
# 97             58
# 95             46

# %%
##TOP 5 HIGHEST BOWLING FIGURES IN T20I FORMAT WHILE BATTING FIRST
temp=df2.nlargest(5,['fi_max_indv_wickets'])
temp[['Match_id','Team1','Team2','Format','Ground','Year','PlayerOfTheMatch','fi_max_indv_wickets']]
# Out:
#     Match_id       Team1      Team2 Format  Ground  Year PlayerOfTheMatch  \
# 91        92   Sri Lanka        UAE   T20I  Mirpur  2016   Lasith Malinga
# 90        91  Bangladesh      India   T20I  Mirpur  2016     Rohit Sharma
# 93        94       India   Pakistan   T20I  Mirpur  2016      Virat Kohli
# 94        95  Bangladesh  Sri Lanka   T20I  Mirpur  2016    Sabbir Rahman
# 97        98  Bangladesh   Pakistan   T20I  Mirpur  2016    Soumya Sarkar
#
#     fi_max_indv_wickets
# 91                    4
# 90                    3
# 93                    3
# 94                    3
# 97                    3

# %%
##TOP 5 HIGHEST BOWLING FIGURES IN T20I FORMAT WHILE BATTING FIRST
temp=df2.nlargest(5,['si_max_indv_wickets'])
temp[['Match_id','Team1','Team2','Format','Ground','Year','PlayerOfTheMatch','si_max_indv_wickets']]
# Out:
#     Match_id       Team1      Team2 Format  Ground  Year PlayerOfTheMatch  \
# 90        91  Bangladesh      India   T20I  Mirpur  2016     Rohit Sharma
# 91        92   Sri Lanka        UAE   T20I  Mirpur  2016   Lasith Malinga
# 93        94       India   Pakistan   T20I  Mirpur  2016      Virat Kohli
# 94        95  Bangladesh  Sri Lanka   T20I  Mirpur  2016    Sabbir Rahman
# 95        96    Pakistan        UAE   T20I  Mirpur  2016     Shoaib Malik
#
#     si_max_indv_wickets
# 90                    3
# 91                    3
# 93                    3
# 94                    3
# 95                    3

# %%
temp=df[df['Selection']=="Batting"]
temp[temp['Toss']==temp['Result']]
# Out:
#      Match_id        Team1       Team2 Format        Ground  Year  \
# 2           3        India    Pakistan    ODI       Sharjah  1984
# 10         11   Bangladesh    Pakistan    ODI    Chattogram  1988
# 15         16        India   Sri Lanka    ODI       Cuttack  1990
# 16         17   Bangladesh   Sri Lanka    ODI       Kolkata  1990
# 20         21        India    Pakistan    ODI       Sharjah  1995
# 26         27   Bangladesh    Pakistan    ODI  Colombo(RPS)  1997
# 34         35        India   Sri Lanka    ODI         Dhaka  2000
# 35         36   Bangladesh    Pakistan    ODI         Dhaka  2000
# 36         37        India    Pakistan    ODI         Dhaka  2000
# 38         39     Pakistan   Sri Lanka    ODI         Dhaka  2000
# 40         41        India         UAE    ODI      Dambulla  2004
# 41         42   Bangladesh    Pakistan    ODI  Colombo(SSC)  2004
# 42         43    Sri Lanka         UAE    ODI      Dambulla  2004
# ...

# %%
#Bar plot of sixes hitten by each team
temp=df.groupby('Team1')['fi_6s'].sum()
temp.plot(kind='bar',color={"red","green","orange","blue","black","skyblue"})
temp
# Out:
# Team1
# Afghanistan    27
# Bangladesh     84
# Hong Kong       8
# India          69
# Pakistan       48
# Sri Lanka      29
# Name: fi_6s, dtype: int64

# %%
#Here we are showing how many teams are there in Team_1 of each country using bar plot
a=df["Team1"].value_counts()
print(a)
a.plot(kind="bar",color={"red","blue","yellow","green","violet","lightblue"})
# Out:
# Bangladesh     40
# India          28
# Sri Lanka      19
# Pakistan       15
# Afghanistan     8
# Hong Kong       4
# Name: Team1, dtype: int64
# <AxesSubplot: >

# %%
#Here we are showing how many teams are there in Team_2 of each country using bar plot
a=df["Team2"].value_counts()
print(a)
a.plot(kind="bar",color={"red","blue","yellow","green","violet","lightblue"})
# Out:
# Sri Lanka      35
# Pakistan       34
# India          26
# Bangladesh      8
# UAE             8
# Hong Kong       2
# Afghanistan     1
# Name: Team2, dtype: int64
# <AxesSubplot: >

# %%
#Pie chart to show the percentage selection of batting and bowling
a=df.groupby("Selection").count()["Toss"]
print(a)
a.plot(kind="pie",subplots=True,autopct='%1.1f%%')
# Out:
# Selection
# Batting    65
# Bowling    49
# Name: Toss, dtype: int64
# array([<AxesSubplot: ylabel='Toss'>], dtype=object)

# %%
#Plot to show the same team won toss and chosen batting and win the match
temp=df[df['Selection']=="Batting"]
a=temp[temp['Toss']==temp['Result']]
print(a)
a.groupby("Toss").count()["Result"].plot(kind='pie',subplots=True,autopct='%1.1f%%')
# Out:
#      Match_id        Team1       Team2 Format        Ground  Year  \
# 2           3        India    Pakistan    ODI       Sharjah  1984
# 10         11   Bangladesh    Pakistan    ODI    Chattogram  1988
# 15         16        India   Sri Lanka    ODI       Cuttack  1990
# 16         17   Bangladesh   Sri Lanka    ODI       Kolkata  1990
# 20         21        India    Pakistan    ODI       Sharjah  1995
# 26         27   Bangladesh    Pakistan    ODI  Colombo(RPS)  1997
# 34         35        India   Sri Lanka    ODI         Dhaka  2000
# 35         36   Bangladesh    Pakistan    ODI         Dhaka  2000
# 36         37        India    Pakistan    ODI         Dhaka  2000
# 38         39     Pakistan   Sri Lanka    ODI         Dhaka  2000
# 40         41        India         UAE    ODI      Dambulla  2004
# 41         42   Bangladesh    Pakistan    ODI  Colombo(SSC)  2004
# 42         43    Sri Lanka         UAE    ODI      Dambulla  2004
# ...

# %%
#•	Plot to show the same team won toss and chosen bowling and win the match
temp=df[df['Selection']=="Bowling"]
a=temp[temp['Toss']==temp['Result']]
print(a)
a.groupby("Toss").count()["Result"].plot(kind='pie',subplots=True,autopct='%1.1f%%')
# Out:
#      Match_id        Team1       Team2 Format        Ground  Year        Toss  \
# 0           1     Pakistan   Sri Lanka    ODI       Sharjah  1984   Sri Lanka
# 1           2        India   Sri Lanka    ODI       Sharjah  1984       India
# 4           5   Bangladesh    Pakistan    ODI      Moratuwa  1986    Pakistan
# 5           6    Sri Lanka  Bangladesh    ODI         Kandy  1986  Bangladesh
# 6           7    Sri Lanka    Pakistan    ODI  Colombo(SSC)  1986   Sri Lanka
# 7           8     Pakistan   Sri Lanka    ODI         Dhaka  1988   Sri Lanka
# 8           9   Bangladesh       India    ODI    Chattogram  1988       India
# 11         12        India    Pakistan    ODI         Dhaka  1988       India
# 12         13   Bangladesh   Sri Lanka    ODI         Dhaka  1988   Sri Lanka
# 13         14        India   Sri Lanka    ODI         Dhaka  1988       India
# 17         18        India   Sri Lanka    ODI       Kolkata  1991       India
# ...

# %%
#Plot to show the percentage of team result
a=df.groupby('Result').count()["Toss"]
a.plot(kind="pie",subplots=True,autopct='%1.1f%%',title="Result")
# Out:
# array([<AxesSubplot: ylabel='Toss'>], dtype=object)

# %%
#plot to show the no of sixes of each team
a=df.groupby("Team1")
c=a["fi_6s"].sum()
b=df.groupby("Team2")
d=b["si_6s"].sum()
e=c+d
e.dropna()
e.plot(title="No of sixes of each team")
# Out:
# <AxesSubplot: title={'center': 'No of sixes of each team'}>

# %%
#plot to show the no of four of each team
a=df.groupby("Team1")
c=a["fi_4s"].sum()
b=df.groupby("Team2")
d=b["si_4s"].sum()
e=c+d
e.dropna()
e.plot(color="red",title="No of fours of each team")
# Out:
# <AxesSubplot: title={'center': 'No of fours of each team'}>
